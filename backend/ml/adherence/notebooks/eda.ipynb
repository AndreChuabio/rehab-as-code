# %% [markdown]
# # Adherence EDA
#
# Stub for exploratory data analysis once production data accumulates.
#
# Plan:
# 1. Pull a snapshot of every patient with `last_active` in the last 60 days using `extract.snapshot()`.
# 2. Convert each to a feature dict via `features.compute()`.
# 3. Inspect distributions of each feature, missing-value patterns, and correlations.
# 4. Define a label: `dropped_out_14d` = no completed session AND no checkin in the next 14 days following snapshot date.
# 5. Compute heuristic precision@k vs random baseline as the bar XGBoost has to beat.
#
# When this notebook produces a useful figure or finding, commit the rendered version with `nbstripout` cleared so reviews stay readable.
